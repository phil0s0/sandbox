# %% [markdown]
# <a href="https://colab.research.google.com/github/phil0s0/sandbox/blob/main/revprog.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
train=pd.read_parquet('store_product/train_BY_hackathon_final.parquet.gzip')
train.head()
# Out:
#    P_ID  PG_ID_3  PG_ID_2  PG_ID_1  NORMAL_PRICE  L_ID   SALES_AREA  \
# 0   130       11        2        1          9.45    14  8846.052099
# 2    53       24        4        2          5.31     5  8355.679930
# 3    36        7        1        1          1.62     2  1721.033617
# 4    96        7        1        1          0.46     4  5928.331385
# 5    83       24        4        2          1.32     4  5928.331385
#
#         DATE  SCHOOL_HOLIDAY EVENT  PROMOTION_TYPE  SALES_PRICE  SALES  \
# 0 2019-10-30             0.0  None               0     9.450000      8
# 2 2021-01-24             0.0  None               0     5.310000      5
# 3 2019-12-20             0.0  None               0     1.620000      7
# 4 2021-02-25             0.0  None               0     0.460000     25
# 5 2020-03-06             0.0  None               1     1.083716     17
#
#                   Id
# 0  130_14_2019-10-30
# 2    53_5_2021-01-24
# 3    36_2_2019-12-20
# 4    96_4_2021-02-25
# ...

# %%
train['DATE'].max()
# Out:
# Timestamp('2022-03-31 00:00:00')

# %%
train.groupby(['L_ID'])['SALES_PRICE'].sum()
# Out:
# L_ID
# 1     1.528142e+06
# 2     1.723876e+06
# 3     1.353804e+06
# 4     1.740314e+06
# 5     1.553242e+06
# 6     1.423870e+06
# 7     1.753147e+06
# 8     1.706977e+06
# 9     1.701819e+06
# 10    1.496604e+06
# 11    1.042727e+06
# 12    1.187018e+06
# 13    1.192201e+06
# 14    1.830964e+06
# 15    1.386644e+06
# 16    1.684761e+06
# 17    1.058796e+06
# 18    1.115453e+06
# 19    1.717101e+06
# 20    1.686601e+06
# Name: SALES_PRICE, dtype: float64
